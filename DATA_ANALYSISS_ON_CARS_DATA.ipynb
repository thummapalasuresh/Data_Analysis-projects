# %% [markdown]
# <a href="https://colab.research.google.com/github/thummapalasuresh/Data_Analysis-projects/blob/main/DATA_ANALYSISS_ON_CARS_DATA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
df= pd.read_csv("/content/2. Cars Data1.csv")
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
df.tail()
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 427  $38,203          2.4        5.0       197.0      21.0         28.0
# 428  $40,083          2.3        5.0       242.0      20.0         26.0
# 429  $42,573          2.9        6.0       268.0      19.0         26.0
# 430  $24,641          1.9        4.0       170.0      22.0         29.0
# 431  $33,112          2.5        5.0       208.0      20.0         27.0
#
#      Weight  Wheelbase  Length
# 427  3450.0      105.0   186.0
# 428  3450.0      105.0   186.0
# ...

# %%
df.isnull()
# Out:
#       Make  Model   Type  Origin  DriveTrain   MSRP  Invoice  EngineSize  \
# 0    False  False  False   False       False  False    False       False
# 1    False  False  False   False       False  False    False       False
# 2    False  False  False   False       False  False    False       False
# 3    False  False  False   False       False  False    False       False
# 4    False  False  False   False       False  False    False       False
# ..     ...    ...    ...     ...         ...    ...      ...         ...
# 427  False  False  False   False       False  False    False       False
# 428  False  False  False   False       False  False    False       False
# 429  False  False  False   False       False  False    False       False
# 430  False  False  False   False       False  False    False       False
# 431  False  False  False   False       False  False    False       False
#
#      Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# ...

# %%
df.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
df.shape
# Out:
# (432, 15)

# %%
df.describe()
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  428.000000  426.000000  428.000000  428.000000   428.000000
# mean     3.196729    5.807512  215.885514   20.060748    26.843458
# std      1.108595    1.558443   71.836032    5.238218     5.741201
# min      1.300000    3.000000   73.000000   10.000000    12.000000
# 25%      2.375000    4.000000  165.000000   17.000000    24.000000
# 50%      3.000000    6.000000  210.000000   19.000000    26.000000
# 75%      3.900000    6.000000  255.000000   21.250000    29.000000
# max      8.300000   12.000000  500.000000   60.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   428.000000  428.000000  428.000000
# mean   3577.953271  108.154206  186.362150
# std     758.983215    8.311813   14.357991
# min    1850.000000   89.000000  143.000000
# 25%    3104.000000  103.000000  178.000000
# 50%    3474.500000  107.000000  187.000000
# 75%    3977.750000  112.000000  194.000000
# ...

# %%
df.describe().transpose()
# Out:
#              count         mean         std     min       25%     50%  \
# EngineSize   428.0     3.196729    1.108595     1.3     2.375     3.0
# Cylinders    426.0     5.807512    1.558443     3.0     4.000     6.0
# Horsepower   428.0   215.885514   71.836032    73.0   165.000   210.0
# MPG_City     428.0    20.060748    5.238218    10.0    17.000    19.0
# MPG_Highway  428.0    26.843458    5.741201    12.0    24.000    26.0
# Weight       428.0  3577.953271  758.983215  1850.0  3104.000  3474.5
# Wheelbase    428.0   108.154206    8.311813    89.0   103.000   107.0
# Length       428.0   186.362150   14.357991   143.0   178.000   187.0
#
#                  75%     max
# EngineSize      3.90     8.3
# Cylinders       6.00    12.0
# Horsepower    255.00   500.0
# MPG_City       21.25    60.0
# MPG_Highway    29.00    66.0
# Weight       3977.75  7190.0
# Wheelbase     112.00   144.0
# Length        194.00   238.0

# %%
df.head(1)
# Out:
#     Make Model Type Origin DriveTrain      MSRP   Invoice  EngineSize  \
# 0  Acura   MDX  SUV   Asia        All  $36,945   $33,337          3.5
#
#    Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 0        6.0       265.0      17.0         23.0  4451.0      106.0   189.0

# %%
x=df.isnull().sum().sum()
x
# Out:
# 62

# %%
df.isnull().values.any()
# Out:
# True

# %%
df['Cylinders'].isnull().values
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
 #df["Cylinders"].mean()

# %%
#df["Cylinders"].fillna(df["Cylinders"].mean(), inplace=True)

# %%
#df.isnull().sum()

# %%
df.dropna(inplace=True)
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df.shape
# Out:
# (428, 15)

# %%
df.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
df["Make"].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %%
df[["Invoice", "Model"]].head(10)
# Out:
#     Invoice                    Model
# 0  $33,337                       MDX
# 1  $21,761            RSX Type S 2dr
# 2  $24,647                   TSX 4dr
# 3  $30,299                    TL 4dr
# 4  $39,014                3.5 RL 4dr
# 5  $41,100   3.5 RL w/Navigation 4dr
# 6  $79,978    NSX coupe 2dr manual S
# 7  $23,508               A4 1.8T 4dr
# 8  $32,506    A41.8T convertible 2dr
# 9  $28,846                A4 3.0 4dr

# %%
df.iloc[:,-2]
# Out:
# 0      106.0
# 1      101.0
# 2      105.0
# 3      108.0
# 4      115.0
#        ...
# 427    105.0
# 428    105.0
# 429    110.0
# 430    101.0
# 431    109.0
# Name: Wheelbase, Length: 428, dtype: float64

# %%
df.iloc[:,-1]
# Out:
# 0      189.0
# 1      172.0
# 2      183.0
# 3      186.0
# 4      197.0
#        ...
# 427    186.0
# 428    186.0
# 429    190.0
# 430    180.0
# 431    186.0
# Name: Length, Length: 428, dtype: float64

# %%
df.iloc[:,:-1].values
# Out:
# array([['Acura', 'MDX', 'SUV', ..., 23.0, 4451.0, 106.0],
#        ['Acura', 'RSX Type S 2dr', 'Sedan', ..., 31.0, 2778.0, 101.0],
#        ['Acura', 'TSX 4dr', 'Sedan', ..., 29.0, 3230.0, 105.0],
#        ...,
#        ['Volvo', 'S80 T6 4dr', 'Sedan', ..., 26.0, 3653.0, 110.0],
#        ['Volvo', 'V40', 'Wagon', ..., 29.0, 2822.0, 101.0],
#        ['Volvo', 'XC70', 'Wagon', ..., 27.0, 3823.0, 109.0]], dtype=object)

# %%
df.iloc[:,-1].values
# Out:
# array([189., 172., 183., 186., 197., 197., 174., 179., 180., 179., 179.,
#        179., 192., 192., 180., 180., 192., 193., 204., 179., 191., 159.,
#        159., 159., 192., 179., 180., 184., 176., 177., 177., 176., 176.,
#        176., 176., 191., 177., 191., 191., 198., 204., 177., 177., 161.,
#        161., 176., 193., 187., 195., 200., 196., 196., 200., 207., 207.,
#        199., 195., 190., 207., 207., 201., 178., 221., 219., 197., 192.,
#        163., 167., 153., 183., 183., 183., 200., 188., 188., 198., 200.,
#        200., 188., 198., 190., 187., 180., 180., 222., 192., 206., 238.,
#        191., 188., 169., 169., 191., 191., 198., 208., 208., 169., 194.,
#        198., 194., 201., 201., 160., 199., 201., 174., 174., 204., 191.,
#        191., 204., 189., 201., 176., 193., 219., 208., 227., 206., 190.,
#        173., 168., 168., 168., 168., 168., 198., 198., 212., 212., 212.,
#        201., 183., 183., 186., 211., 218., 188., 178., 198., 208., 199.,
# ...

# %%
df.iloc[1].values
# Out:
# array(['Acura', 'RSX Type S 2dr', 'Sedan', 'Asia', 'Front', '$23,820 ',
#        '$21,761 ', 2.0, 4.0, 200.0, 24.0, 31.0, 2778.0, 101.0, 172.0],
#       dtype=object)

# %%
df.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %%
df["Origin"].head(15)
# Out:
# 0       Asia
# 1       Asia
# 2       Asia
# 3       Asia
# 4       Asia
# 5       Asia
# 6       Asia
# 7     Europe
# 8     Europe
# 9     Europe
# 10    Europe
# 11    Europe
# 12    Europe
# 13    Europe
# 14    Europe
# Name: Origin, dtype: object

# %%
df[df['Origin'].isin(['Asia','Europe','USA'])]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df["Origin"].value_counts()
# Out:
# Asia      158
# USA       147
# Europe    123
# Name: Origin, dtype: int64

# %%
df[df['Origin'].isin(['USA'])]
# Out:
#        Make                Model   Type Origin DriveTrain      MSRP   Invoice  \
# 48    Buick              Rainier    SUV    USA        All  $37,895   $34,357
# 49    Buick        Rendezvous CX    SUV    USA      Front  $26,545   $24,085
# 50    Buick   Century Custom 4dr  Sedan    USA      Front  $22,180   $20,351
# 51    Buick   LeSabre Custom 4dr  Sedan    USA      Front  $26,470   $24,282
# 52    Buick         Regal LS 4dr  Sedan    USA      Front  $24,895   $22,835
# ..      ...                  ...    ...    ...        ...       ...       ...
# 351  Saturn             lon3 4dr  Sedan    USA      Front  $15,825   $14,811
# 352  Saturn  lon2 quad coupe 2dr  Sedan    USA      Front  $14,850   $13,904
# 353  Saturn  lon3 quad coupe 2dr  Sedan    USA      Front  $16,350   $15,299
# 354  Saturn           L300-2 4dr  Sedan    USA      Front  $21,410   $19,801
# 355  Saturn               L300 2  Wagon    USA      Front  $23,560   $21,779
#
# ...

# %%
df[df['Weight']>4000].head(10) #finding greater than values
# Out:
#      Make                           Model    Type  Origin DriveTrain  \
# 0   Acura                             MDX     SUV    Asia        All
# 15   Audi  A4 3.0 Quattro convertible 2dr   Sedan  Europe        All
# 17   Audi              A6 4.2 Quattro 4dr   Sedan  Europe        All
# 18   Audi                A8 L Quattro 4dr   Sedan  Europe        All
# 20   Audi                        RS 6 4dr  Sports  Europe      Front
# 24   Audi            A6 3.0 Avant Quattro   Wagon  Europe        All
# 26    BMW                         X3 3.0i     SUV  Europe        All
# 27    BMW                         X5 4.4i     SUV  Europe        All
# 41    BMW                        745i 4dr   Sedan  Europe       Rear
# 42    BMW                       745Li 4dr   Sedan  Europe       Rear
#
#         MSRP   Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# 0   $36,945   $33,337          3.5        6.0       265.0      17.0
# 15  $44,240   $40,075          3.0        6.0       220.0      18.0
# ...

# %%
df[~(df['Weight']>4000)]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  $46,100
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df[~(df['Weight']>4000)].head(10)
# Out:
#      Make                      Model    Type  Origin DriveTrain      MSRP  \
# 1   Acura             RSX Type S 2dr   Sedan    Asia      Front  $23,820
# 2   Acura                    TSX 4dr   Sedan    Asia      Front  $26,990
# 3   Acura                     TL 4dr   Sedan    Asia      Front  $33,195
# 4   Acura                 3.5 RL 4dr   Sedan    Asia      Front  $43,755
# 5   Acura    3.5 RL w/Navigation 4dr   Sedan    Asia      Front  $46,100
# 6   Acura     NSX coupe 2dr manual S  Sports    Asia       Rear  $89,765
# 7    Audi                A4 1.8T 4dr   Sedan  Europe      Front  $25,940
# 8    Audi     A41.8T convertible 2dr   Sedan  Europe      Front  $35,940
# 9    Audi                 A4 3.0 4dr   Sedan  Europe      Front  $31,840
# 10   Audi  A4 3.0 Quattro 4dr manual   Sedan  Europe        All  $33,430
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 1   $21,761          2.0        4.0       200.0      24.0         31.0
# ...

# %%
df['MPG_City']
# Out:
# 0      17.0
# 1      24.0
# 2      22.0
# 3      20.0
# 4      18.0
#        ...
# 427    21.0
# 428    20.0
# 429    19.0
# 430    22.0
# 431    20.0
# Name: MPG_City, Length: 428, dtype: float64

# %%
df['MPG_City']=df['MPG_City'].apply (lambda x:x+3)
df.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      38.0         23.0  4451.0
# 1         2.0        4.0       200.0      45.0         31.0  2778.0
# 2         2.4        4.0       200.0      43.0         29.0  3230.0
# 3         3.2        6.0       270.0      41.0         28.0  3575.0
# 4         3.5        6.0       225.0      39.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0
