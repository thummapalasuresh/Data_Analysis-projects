# %% [markdown]
# <a href="https://colab.research.google.com/github/thummapalasuresh/Data_Analysis-projects/blob/main/IPL_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ec3c2cd1-8d08-47d6-9aae-ceae92c5fc6b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ec3c2cd1-8d08-47d6-9aae-ceae92c5fc6b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving IPL.jpg to IPL.jpg

# %%
Image('IPL.jpg',width=700)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('/content/IPLData.csv')
df.columns
df.Player_Type.unique()
# Out:
# array(['Batter', 'Bowler ', 'Keeper', 'Allrounder'], dtype=object)

# %%
df
# Out:
#          Player Name       Team Nationality Player_Type  Capped  \
# 0     Shikhar Dhawan     Punjab      Indian      Batter       1
# 1      Shreyas Iyer     Kolkata      Indian      Batter       1
# 2     Faf Du Plessis  Bangalore    Overseas      Batter       1
# 3     Manish Pandey     Lucknow      Indian      Batter       1
# 4    Shimron Hetmyer  Rajasthan    Overseas      Batter       1
# ..               ...        ...         ...         ...     ...
# 230     Ravi Bishnoi    Lucknow      Indian     Bowler        1
# 231  Ruturaj Gaikwad    Chennai      Indian      Batter       1
# 232    Sunil Narine     Kolkata    Overseas  Allrounder       1
# 233  Kieron Pollard      Mumbai    Overseas  Allrounder       1
# 234    Anrich Nortje      Delhi    Overseas     Bowler        1
#
#      Matches_Played    Runs  Average  Strike_Rate  Wickets  Bowling_average  \
# 0             192.0  5783.0    34.63       126.60      4.0            16.50
# ...

# %%
df.columns
# Out:
# Index(['Player Name', 'Team', 'Nationality', 'Player_Type', 'Capped',
#        'Matches_Played', 'Runs', 'Average', 'Strike_Rate', 'Wickets',
#        'Bowling_average', 'Economy', 'Bowling_Strike_Rate', 'Catches',
#        'Run_outs', 'Stumps'],
#       dtype='object')

# %%
bowlers=df.loc[(df["Player_Type"]== "Bowler ")]
bowlers
# Out:
#             Player Name       Team Nationality Player_Type  Capped  \
# 36       Kagiso Rabada      Punjab    Overseas     Bowler        1
# 37         Trent Boult   Rajasthan    Overseas     Bowler        1
# 38      Mohammad Shami     Gujarat      Indian     Bowler        1
# 39          T Natarajan  Hyderabad      Indian     Bowler        1
# 40       Deepak Chahar     Chennai      Indian     Bowler        1
# ..                  ...        ...         ...         ...     ...
# 214  Varun Chakravarthy    Kolkata      Indian     Bowler        1
# 215      Jasprit Bumrah     Mumbai      Indian     Bowler        1
# 227         Umran Malik  Hyderabad      Indian     Bowler        2
# 230        Ravi Bishnoi    Lucknow      Indian     Bowler        1
# 234       Anrich Nortje      Delhi    Overseas     Bowler        1
#
#      Matches_Played   Runs  Average  Strike_Rate  Wickets  Bowling_average  \
# 36             50.0  138.0    13.80       102.99     76.0            20.53
# ...

# %%
batters=df.loc[(df["Player_Type"]== 'Batter')]
batters
# Out:
#                 Player Name       Team Nationality Player_Type  Capped  \
# 0            Shikhar Dhawan     Punjab      Indian      Batter       1
# 1             Shreyas Iyer     Kolkata      Indian      Batter       1
# 2            Faf Du Plessis  Bangalore    Overseas      Batter       1
# 3            Manish Pandey     Lucknow      Indian      Batter       1
# 4           Shimron Hetmyer  Rajasthan    Overseas      Batter       1
# 5             Robin Uthappa    Chenai       Indian      Batter       1
# 6                 Jason Roy    Gujarat    Overseas      Batter       1
# 7          Devdutt Padikkal  Rajasthan      Indian      Batter       1
# 8               Priyam Garg  Hyderabad      Indian      Batter       1
# 9       Abhinav Sadarangani   Gujarat       Indian      Batter       0
# 10            Dewald Brevis     Mumbai    Overseas      Batter       0
# 11            Ashwin Hebbar      Delhi      Indian      Batter       0
# ...

# %%
batters_new=batters.loc[(batters["Capped"]== 1)]
batters_new
capped_batters=batters_new[['Player Name', 'Team','Nationality','Runs','Average','Strike_Rate','Matches_Played']]
capped_batters
capped_batters.head()
# Out:
#        Player Name       Team Nationality    Runs  Average  Strike_Rate  \
# 0   Shikhar Dhawan     Punjab      Indian  5783.0    34.63       126.60
# 1    Shreyas Iyer     Kolkata      Indian  2375.0    31.67       123.96
# 2   Faf Du Plessis  Bangalore    Overseas  2935.0    34.94       131.09
# 3   Manish Pandey     Lucknow      Indian  3560.0    30.69       121.83
# 4  Shimron Hetmyer  Rajasthan    Overseas   517.0    25.85       151.17
#
#    Matches_Played
# 0           192.0
# 1            87.0
# 2           100.0
# 3           154.0
# 4            31.0

# %%
bowlers=df.loc[(df["Player_Type"]== "Bowler ")]
bowlers
bowlers_new=bowlers.loc[(bowlers["Capped"]== 1)]
bowlers_new
capped_bowlers=bowlers_new[['Player Name', 'Team','Nationality','Matches_Played','Wickets','Bowling_average','Economy','Bowling_Strike_Rate']]
capped_bowlers.head()
# Out:
#         Player Name       Team Nationality  Matches_Played  Wickets  \
# 36   Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 37     Trent Boult   Rajasthan    Overseas            62.0     76.0
# 38  Mohammad Shami     Gujarat      Indian            77.0     79.0
# 39      T Natarajan  Hyderabad      Indian            24.0     20.0
# 40   Deepak Chahar     Chennai      Indian            63.0     59.0
#
#     Bowling_average  Economy  Bowling_Strike_Rate
# 36            20.53     8.21                15.00
# 37            26.09     8.40                18.64
# 38            30.41     8.63                21.14
# 39            34.40     8.24                25.05
# 40            29.19     7.80                22.44

# %%
keepers= df.loc[(df["Player_Type"]== "Keeper")]
keepers
keepers_new= keepers.loc[(keepers["Capped"]==1)]
keepers_new
capped_keepers= keepers_new[['Player Name', 'Team','Nationality','Matches_Played','Runs','Average','Strike_Rate','Catches','Run_outs','Stumps']]
capped_keepers
# Out:
#            Player Name       Team Nationality  Matches_Played    Runs  \
# 105    Quinton De Kock    Lucknow    Overseas            77.0  2256.0
# 106      Ambati Rayudu    Chennai      Indian           175.0  3916.0
# 107       Ishan Kishan     Mumbai      Indian            61.0  1452.0
# 108     Jonny Bairstow     Punjab    Overseas            28.0  1038.0
# 109     Dinesh Karthik  Bangalore      Indian           213.0  4046.0
# 110   Nicholas Pooran   Hyderabad    Overseas            33.0   606.0
# 111          KS Bharat      Delhi      Indian             8.0   191.0
# 112         Anuj Rawat  Bangalore      Indian             1.0     0.0
# 113  Prabhsimran Singh     Punjab      Indian             5.0    50.0
# 114   Sheldon Jackson     Kolkata    Overseas             4.0    38.0
# 117      Sam Billings     Kolkata    Overseas            22.0   334.0
# 118   Wridhhiman Saha     Gujarat      Indian           133.0  2110.0
# ...

# %%
Allrounders= df.loc[(df["Player_Type"]== "Allrounder")]
Allrounders
Allrounder_new= Allrounders.loc[(Allrounders["Capped"]==1)]
Allrounder_new
# Out:
#               Player Name       Team Nationality Player_Type  Capped  \
# 127  Ravichandran Ashwin   Rajasthan      Indian  Allrounder       1
# 128          Pat Cummins     Kolkata    Overseas  Allrounder       1
# 129         Dwayne Bravo     Chennai    Overseas  Allrounder       1
# 130          Nitish Rana     Kolkata      Indian  Allrounder       1
# 131          Jason Holder    Lucknow    Overseas  Allrounder       1
# 132         Harshal Patel  Bangalore      Indian  Allrounder       1
# 133          Deepak Hooda    Lucknow      Indian  Allrounder       1
# 135     Washington Sundar  Hyderabad      Indian  Allrounder       1
# 136         Krunal Pandya    Lucknow      Indian  Allrounder       1
# 137        Mitchell Marsh      Delhi    Overseas  Allrounder       1
# 138           Riyan Parag  Rajasthan      Indian  Allrounder       1
# 139      Abhishek Sharma   Hyderabad      Indian  Allrounder       1
# 140        Sarfaraz Khan       Delhi      Indian  Allrounder       1
# ...

# %%
df.columns
# Out:
# Index(['Player Name', 'Team', 'Nationality', 'Player_Type', 'Capped',
#        'Matches_Played', 'Runs', 'Average', 'Strike_Rate', 'Wickets',
#        'Bowling_average', 'Economy', 'Bowling_Strike_Rate', 'Catches',
#        'Run_outs', 'Stumps'],
#       dtype='object')

# %%
capped_Allrounders = Allrounder_new[['Player Name', 'Team', 'Nationality','Matches_Played','Runs','Average','Strike_Rate',
'Wickets','Bowling_average','Economy','Bowling_Strike_Rate']]
capped_Allrounders
# Out:
#               Player Name       Team Nationality  Matches_Played    Runs  \
# 127  Ravichandran Ashwin   Rajasthan      Indian           167.0   456.0
# 128          Pat Cummins     Kolkata    Overseas            37.0   316.0
# 129         Dwayne Bravo     Chennai    Overseas           151.0  1537.0
# 130          Nitish Rana     Kolkata      Indian            77.0  1820.0
# 131          Jason Holder    Lucknow    Overseas            26.0   189.0
# 132         Harshal Patel  Bangalore      Indian            63.0   187.0
# 133          Deepak Hooda    Lucknow      Indian            80.0   785.0
# 135     Washington Sundar  Hyderabad      Indian            42.0   217.0
# 136         Krunal Pandya    Lucknow      Indian            84.0  1143.0
# 137        Mitchell Marsh      Delhi    Overseas            21.0   225.0
# 138           Riyan Parag  Rajasthan      Indian            30.0   339.0
# 139      Abhishek Sharma   Hyderabad      Indian            22.0   241.0
# ...

# %% [markdown]
# #making null or NaN values 0

# %%
capped_batters=capped_batters.fillna(0)
capped_bowlers=capped_bowlers.fillna(0)
capped_Allrounders=capped_Allrounders.fillna(0)
capped_keepers=capped_keepers.fillna(0)

# %% [markdown]
# #checking null values in data

# %%
print(capped_batters.isna().sum())
print(capped_bowlers.isna().sum())
print(capped_Allrounders.isna().sum())
print(capped_keepers.isna().sum())
# Out:
# Player Name       0
# Team              0
# Nationality       0
# Runs              0
# Average           0
# Strike_Rate       0
# Matches_Played    0
# dtype: int64
# Player Name            0
# Team                   0
# Nationality            0
# Matches_Played         0
# Wickets                0
# Bowling_average        0
# Economy                0
# Bowling_Strike_Rate    0
# dtype: int64
# Player Name            0
# Team                   0
# Nationality            0
# Matches_Played         0
# Runs                   0
# Average                0
# Strike_Rate            0
# Wickets                0
# Bowling_average        0
# Economy                0
# Bowling_Strike_Rate    0
# dtype: int64
# Player Name       0
# Team              0
# Nationality       0
# Matches_Played    0
# Runs              0
# Average           0
# Strike_Rate       0
# Catches           0
# Run_outs          0
# Stumps            0
# dtype: int64

# %% [markdown]
# #Top_Bats_Men

# %%
top_batters=capped_batters.loc[(capped_batters['Average'] > 32.0)]
top_batters
# Out:
#          Player Name       Team Nationality    Runs  Average  Strike_Rate  \
# 0     Shikhar Dhawan     Punjab      Indian  5783.0    34.63       126.60
# 2     Faf Du Plessis  Bangalore    Overseas  2935.0    34.94       131.09
# 19     David Warner       Delhi    Overseas  5449.0    41.60       139.97
# 26     David Miller     Gujarat    Overseas  1974.0    32.90       136.51
# 207  Kane Williamson  Hyderabad    Overseas  1885.0    40.11       131.27
# 208      Virat Kohli  Bangalore      Indian  6283.0    37.40       129.95
# 212        KL Rahul     Lucknow      Indian  3273.0    47.43       136.38
# 231  Ruturaj Gaikwad    Chennai      Indian   839.0    46.61       132.13
#
#      Matches_Played
# 0             192.0
# 2             100.0
# 19            150.0
# 26             89.0
# 207            63.0
# 208           207.0
# 212            94.0
# 231            22.0

# %% [markdown]
# #Sort the data in descending order as per relative with parameter

# %%
top_batters_avg = top_batters.sort_values('Average', ascending=False)
top_batters_str = top_batters.sort_values('Strike_Rate', ascending=False)
top_batters_run = top_batters.sort_values('Runs', ascending=False)
top_batters_mtc = top_batters.sort_values('Matches_Played', ascending=False)

# %%
top_batters_avg
# Out:
#          Player Name       Team Nationality    Runs  Average  Strike_Rate  \
# 212        KL Rahul     Lucknow      Indian  3273.0    47.43       136.38
# 231  Ruturaj Gaikwad    Chennai      Indian   839.0    46.61       132.13
# 19     David Warner       Delhi    Overseas  5449.0    41.60       139.97
# 207  Kane Williamson  Hyderabad    Overseas  1885.0    40.11       131.27
# 208      Virat Kohli  Bangalore      Indian  6283.0    37.40       129.95
# 2     Faf Du Plessis  Bangalore    Overseas  2935.0    34.94       131.09
# 0     Shikhar Dhawan     Punjab      Indian  5783.0    34.63       126.60
# 26     David Miller     Gujarat    Overseas  1974.0    32.90       136.51
#
#      Matches_Played
# 212            94.0
# 231            22.0
# 19            150.0
# 207            63.0
# 208           207.0
# 2             100.0
# 0             192.0
# 26             89.0

# %%
top_batters_str
# Out:
#          Player Name       Team Nationality    Runs  Average  Strike_Rate  \
# 19     David Warner       Delhi    Overseas  5449.0    41.60       139.97
# 26     David Miller     Gujarat    Overseas  1974.0    32.90       136.51
# 212        KL Rahul     Lucknow      Indian  3273.0    47.43       136.38
# 231  Ruturaj Gaikwad    Chennai      Indian   839.0    46.61       132.13
# 207  Kane Williamson  Hyderabad    Overseas  1885.0    40.11       131.27
# 2     Faf Du Plessis  Bangalore    Overseas  2935.0    34.94       131.09
# 208      Virat Kohli  Bangalore      Indian  6283.0    37.40       129.95
# 0     Shikhar Dhawan     Punjab      Indian  5783.0    34.63       126.60
#
#      Matches_Played
# 19            150.0
# 26             89.0
# 212            94.0
# 231            22.0
# 207            63.0
# 2             100.0
# 208           207.0
# 0             192.0

# %%
top_batters_run
# Out:
#          Player Name       Team Nationality    Runs  Average  Strike_Rate  \
# 208      Virat Kohli  Bangalore      Indian  6283.0    37.40       129.95
# 0     Shikhar Dhawan     Punjab      Indian  5783.0    34.63       126.60
# 19     David Warner       Delhi    Overseas  5449.0    41.60       139.97
# 212        KL Rahul     Lucknow      Indian  3273.0    47.43       136.38
# 2     Faf Du Plessis  Bangalore    Overseas  2935.0    34.94       131.09
# 26     David Miller     Gujarat    Overseas  1974.0    32.90       136.51
# 207  Kane Williamson  Hyderabad    Overseas  1885.0    40.11       131.27
# 231  Ruturaj Gaikwad    Chennai      Indian   839.0    46.61       132.13
#
#      Matches_Played
# 208           207.0
# 0             192.0
# 19            150.0
# 212            94.0
# 2             100.0
# 26             89.0
# 207            63.0
# 231            22.0

# %%
top_batters_mtc
# Out:
#          Player Name       Team Nationality    Runs  Average  Strike_Rate  \
# 208      Virat Kohli  Bangalore      Indian  6283.0    37.40       129.95
# 0     Shikhar Dhawan     Punjab      Indian  5783.0    34.63       126.60
# 19     David Warner       Delhi    Overseas  5449.0    41.60       139.97
# 2     Faf Du Plessis  Bangalore    Overseas  2935.0    34.94       131.09
# 212        KL Rahul     Lucknow      Indian  3273.0    47.43       136.38
# 26     David Miller     Gujarat    Overseas  1974.0    32.90       136.51
# 207  Kane Williamson  Hyderabad    Overseas  1885.0    40.11       131.27
# 231  Ruturaj Gaikwad    Chennai      Indian   839.0    46.61       132.13
#
#      Matches_Played
# 208           207.0
# 0             192.0
# 19            150.0
# 2             100.0
# 212            94.0
# 26             89.0
# 207            63.0
# 231            22.0

# %% [markdown]
# From our analysis if we rank for top in a list:
# 1.David warner
# 2.KL Rahul
# 3.ViratKohli

# %%
capped_bowlers
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 37          Trent Boult   Rajasthan    Overseas            62.0     76.0
# 38       Mohammad Shami     Gujarat      Indian            77.0     79.0
# 39           T Natarajan  Hyderabad      Indian            24.0     20.0
# 40        Deepak Chahar     Chennai      Indian            63.0     59.0
# 41      Prasidh Krishna   Rajasthan      Indian            34.0     30.0
# 42       Lockei Ferguson    Gujarat    Overseas            22.0     24.0
# 43       Josh Hazlewood   Bangalore    Overseas            12.0     12.0
# 45     Bhuvneshwar Kumar  Hyderabad      Indian           132.0    142.0
# 46       Shardul Thakur       Delhi      Indian            61.0     67.0
# 47    Mustafizur Rahman       Delhi    Overseas            38.0     38.0
# 48         Kuldeep Yadav      Delhi      Indian            45.0     40.0
# ...

# %% [markdown]
# #Top_Bowlers

# %%
top_bowlers= capped_bowlers.loc[(capped_bowlers['Bowling_average'] <= 24.0)]
top_bowlers
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
#
# ...

# %% [markdown]
# compare with some parameters...

# %%
top_bowlers_avg= top_bowlers.sort_values('Bowling_average', ascending= True)
top_bowlers_str= top_bowlers.sort_values('Bowling_Strike_Rate', ascending= True)
top_bowlers_wick= top_bowlers.sort_values('Wickets', ascending= False)
top_bowlers_eco= top_bowlers.sort_values('Economy', ascending= True)
top_bowlers_mtc= top_bowlers.sort_values('Matches_Played', ascending= False)

# %%
top_bowlers_avg
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
#
# ...

# %%
top_bowlers_str
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
#
# ...

# %%
top_bowlers_eco
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
#
# ...

# %%
top_bowlers_wick
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
#
# ...

# %%
top_bowlers_mtc
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
#
# ...

# %% [markdown]
# # From above data we can rank from------->                                    kagiso rabada,                                                        jasprit bumrah ,                                                     Yuzvendra chahal  ,                                                   Nathan coulter

# %%
top_allrouders = capped_Allrounders.loc[(capped_Allrounders['Strike_Rate'] >= 140.0)]
top_allrouders.columns
# Out:
# Index(['Player Name', 'Team', 'Nationality', 'Matches_Played', 'Runs',
#        'Average', 'Strike_Rate', 'Wickets', 'Bowling_average', 'Economy',
#        'Bowling_Strike_Rate'],
#       dtype='object')

# %%
top_allrouders_avg=  top_allrouders.sort_values('Average', ascending=False)
top_allrouders_strike_rate= top_allrouders.sort_values('Strike_Rate', ascending=False)
top_allrouders_runs= top_allrouders.sort_values('Runs', ascending=False)
top_allrouders_matches= top_allrouders.sort_values('Matches_Played', ascending=False)
top_allrouders_bowling_avg= top_allrouders.sort_values('Bowling_average', ascending=False)
top_allrouders_bowling_strikerate= top_allrouders.sort_values('Bowling_Strike_Rate', ascending=False)
top_allrouders_wickets= top_allrouders.sort_values('Wickets', ascending=False)
top_allrouders_economy= top_allrouders.sort_values('Economy', ascending=False)

# %%
top_allrouders_avg
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
top_allrouders_strike_rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
#
# ...

# %%
top_allrouders_runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
top_allrouders_matches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
top_allrouders_bowling_avg
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
top_allrouders_bowling_strikerate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
top_allrouders_wickets
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
top_allrouders_economy
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
#
# ...

# %% [markdown]
# From aove data rank from top all rounders are
#
# 1. Andre Russell
# 2.  Sunil Narine
#
# 3. hardik pandya
# 4. jofra archer

# %% [markdown]
# #Top_Keepers

# %%
capped_keepers.columns
# Out:
# Index(['Player Name', 'Team', 'Nationality', 'Matches_Played', 'Runs',
#        'Average', 'Strike_Rate', 'Catches', 'Run_outs', 'Stumps'],
#       dtype='object')

# %%
top_keepers = capped_keepers.loc[(capped_keepers['Average'] >25.0)]

top_keepers_avg= top_keepers.sort_values('Average', ascending=False)
top_keepers_strike_rate=top_keepers.sort_values('Strike_Rate', ascending=False)
top_keepers_catches=top_keepers.sort_values('Catches', ascending=False)
top_keepers_Runs=top_keepers.sort_values('Runs', ascending=False)
top_keepers_matches=top_keepers.sort_values('Matches_Played', ascending=False)
top_keepers_Run_outs=top_keepers.sort_values('Run_outs', ascending=False)
top_keepers_Stumps= top_keepers.sort_values('Stumps', ascending=False)

# %%
top_keepers_avg
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 108       142.20     18.0       1.0     4.0
# ...

# %%
top_keepers_strike_rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 219       150.00     34.0       3.0     1.0
# ...

# %%
top_keepers_catches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
top_keepers_Runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
top_keepers_matches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
top_keepers_Run_outs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
top_keepers_Stumps
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %% [markdown]
# From aove data rank from top all keepers are  Top 3 keepers are:
#
# 1. MS. Dhoni
# 2. Dinesh Karthik
#
# 3. Rishabh pant

# %% [markdown]
# #Visualization for Enhanced Analysis

# %% [markdown]
# #batters_visualization....

# %%
top_batters.columns
# Out:
# Index(['Player Name', 'Team', 'Nationality', 'Runs', 'Average', 'Strike_Rate',
#        'Matches_Played'],
#       dtype='object')

# %% [markdown]
# visualize the batters data

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Strike_Rate',data=top_batters)

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Runs',data=top_batters)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Average',data=top_batters)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Matches_Played',data=top_batters)

# %% [markdown]
# #bowlers_data

# %%
top_bowlers.columns
# Out:
# Index(['Player Name', 'Team', 'Nationality', 'Matches_Played', 'Wickets',
#        'Bowling_average', 'Economy', 'Bowling_Strike_Rate'],
#       dtype='object')

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Bowling_average',data=top_bowlers)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Economy',data=top_bowlers)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Bowling_Strike_Rate',data=top_bowlers)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Wickets',data=top_bowlers)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Matches_Played',data=top_bowlers)

# %% [markdown]
# #All_rounders Visualization

# %%
top_allrouders.columns
# Out:
# Index(['Player Name', 'Team', 'Nationality', 'Matches_Played', 'Runs',
#        'Average', 'Strike_Rate', 'Wickets', 'Bowling_average', 'Economy',
#        'Bowling_Strike_Rate'],
#       dtype='object')

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Strike_Rate',data=top_allrouders)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Average',data=top_allrouders)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Matches_Played',data=top_allrouders)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Runs',data=top_allrouders)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Bowling_average',data=top_allrouders)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Economy',data=top_allrouders)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Bowling_Strike_Rate',data=top_allrouders)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Wickets',data=top_allrouders)

# %% [markdown]
# #Top_keepers Visualization

# %%
top_keepers.columns
# Out:
# Index(['Player Name', 'Team', 'Nationality', 'Matches_Played', 'Runs',
#        'Average', 'Strike_Rate', 'Catches', 'Run_outs', 'Stumps'],
#       dtype='object')

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Average',data=top_keepers)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Runs',data=top_keepers)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Strike_Rate',data=top_keepers)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Catches',data=top_keepers)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Run_outs',data=top_keepers)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Stumps',data=top_keepers)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name',y='Matches_Played',data=top_keepers)

# %%
top_batters.columns
# Out:
# Index(['Player Name', 'Team', 'Nationality', 'Runs', 'Average', 'Strike_Rate',
#        'Matches_Played'],
#       dtype='object')

# %%
top_batters.reset_index(drop=True)
# Out:
#        Player Name       Team Nationality    Runs  Average  Strike_Rate  \
# 0   Shikhar Dhawan     Punjab      Indian  5783.0    34.63       126.60
# 1   Faf Du Plessis  Bangalore    Overseas  2935.0    34.94       131.09
# 2    David Warner       Delhi    Overseas  5449.0    41.60       139.97
# 3    David Miller     Gujarat    Overseas  1974.0    32.90       136.51
# 4  Kane Williamson  Hyderabad    Overseas  1885.0    40.11       131.27
# 5      Virat Kohli  Bangalore      Indian  6283.0    37.40       129.95
# 6        KL Rahul     Lucknow      Indian  3273.0    47.43       136.38
# 7  Ruturaj Gaikwad    Chennai      Indian   839.0    46.61       132.13
#
#    Matches_Played
# 0           192.0
# 1           100.0
# 2           150.0
# 3            89.0
# 4            63.0
# 5           207.0
# 6            94.0
# 7            22.0

# %% [markdown]
# #Visualization as per top 3 bats_men

# %%
match_values= [top_batters.iloc[6]['Matches_Played'],top_batters.iloc[2]['Matches_Played'],top_batters.iloc[5]['Matches_Played']]
run_values= [top_batters.iloc[6]['Runs'],top_batters.iloc[2]['Runs'],top_batters.iloc[5]['Runs']]
avg_values=[top_batters.iloc[6]['Average'],top_batters.iloc[2]['Average'],top_batters.iloc[5]['Average']]
strike_rate=[top_batters.iloc[6]['Strike_Rate'],top_batters.iloc[2]['Strike_Rate'],top_batters.iloc[5]['Strike_Rate']]
player_name= [top_batters.iloc[6]['Player Name'],top_batters.iloc[2]['Player Name'],top_batters.iloc[5]['Player Name']]
labels=player_name

# %%
fig,axes=plt.subplots(2,2, figsize=(10,10))
axes[0][0].set_title('Matches_Played')
axes[0][1].set_title('Runs in IPL')
axes[1][0].set_title('Strike_rate')
axes[1][1].set_title('Average')
sns.barplot(x=labels,y=match_values,ax=axes[0][0])
sns.barplot(x=labels,y=run_values,ax=axes[0][1])
sns.barplot(x=labels,y=strike_rate,ax=axes[1][0])
sns.barplot(x=labels,y=avg_values,ax=axes[1][1])

# %% [markdown]
# #Visualization as per top Allrounders

# %%
top_allrouders.columns
# Out:
# Index(['Player Name', 'Team', 'Nationality', 'Matches_Played', 'Runs',
#        'Average', 'Strike_Rate', 'Wickets', 'Bowling_average', 'Economy',
#        'Bowling_Strike_Rate'],
#       dtype='object')

# %%
top_allrouders.reset_index(drop=True)
# Out:
#         Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 0      Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 1        K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 2      Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 3    Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 4        Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 5     Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 6     Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 7      Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 8         Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 9     Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 10  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
#
# ...

# %%
match_values= [top_allrouders.iloc[5]['Matches_Played'],top_allrouders.iloc[9]['Matches_Played'],top_allrouders.iloc[6]['Matches_Played']]
Runs_values= [top_allrouders.iloc[5]['Runs'],top_allrouders.iloc[9]['Runs'],top_allrouders.iloc[6]['Runs']]
Average_values= [top_allrouders.iloc[5]['Average'],top_allrouders.iloc[9]['Average'],top_allrouders.iloc[6]['Average']]
Strike_Rate_values=[top_allrouders.iloc[5]['Strike_Rate'],top_allrouders.iloc[9]['Strike_Rate'],top_allrouders.iloc[6]['Strike_Rate']]
Bowling_Strike_Rate_values= [top_allrouders.iloc[5]['Bowling_Strike_Rate'],top_allrouders.iloc[9]['Bowling_Strike_Rate'],top_allrouders.iloc[6]['Bowling_Strike_Rate']]
Bowling_average_values=[top_allrouders.iloc[5]['Bowling_average'],top_allrouders.iloc[9]['Bowling_average'],top_allrouders.iloc[6]['Bowling_average']]
Wickets_values= [top_allrouders.iloc[5]['Wickets'],top_allrouders.iloc[9]['Wickets'],top_allrouders.iloc[6]['Wickets']]
economy_values= [top_allrouders.iloc[5]['Economy'],top_allrouders.iloc[9]['Economy'],top_allrouders.iloc[6]['Economy']]
labels= [top_allrouders.iloc[5]['Player Name'],top_allrouders.iloc[9]['Player Name'],top_allrouders.iloc[6]['Player Name']]

# %%
fig,axes=plt.subplots(4,2, figsize=(20,20))
axes[0][0].set_title('Matches_Played')
axes[0][1].set_title('Runs_values')
axes[1][0].set_title('Average_values')
axes[1][1].set_title('Strike_Rate_values')
axes[2][0].set_title('Bowling_Strike_Rate_values')
axes[2][1].set_title('Bowling_average_values')
axes[3][0].set_title('Wickets_values')
axes[3][1].set_title('economy_values')

sns.barplot(x=labels, y=match_values, ax=axes[0][0])
sns.barplot(x=labels, y=Runs_values, ax=axes[0][1])
sns.barplot(x=labels, y=Average_values, ax=axes[1][0])
sns.barplot(x=labels, y=Strike_Rate_values, ax=axes[1][1])
sns.barplot(x=labels, y=Bowling_Strike_Rate_values, ax=axes[2][0])
sns.barplot(x=labels, y=Bowling_average_values, ax=axes[2][1])
sns.barplot(x=labels, y=Wickets_values, ax=axes[3][0])
sns.barplot(x=labels, y=economy_values, ax=axes[3][1])

# %% [markdown]
# #top_bowlers visualization

# %%
top_bowlers.columns
# Out:
# Index(['Player Name', 'Team', 'Nationality', 'Matches_Played', 'Wickets',
#        'Bowling_average', 'Economy', 'Bowling_Strike_Rate'],
#       dtype='object')

# %%
top_bowlers.reset_index(drop=True)
# Out:
#             Player Name       Team Nationality  Matches_Played  Wickets  \
# 0        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 1     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 2            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 3           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 4        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 5          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 6          Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 7   Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 8       Arshdeep Singh      Punjab      Indian            23.0     30.0
# 9    Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 10       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 11        Anrich Nortje      Delhi    Overseas            24.0     34.0
#
# ...

# %%
labels= [top_bowlers.iloc[10]['Player Name'],top_bowlers.iloc[0]['Player Name'],top_bowlers.iloc[7]['Player Name'],top_bowlers.iloc[1]['Player Name']]
Matches_Played_values= [top_bowlers.iloc[10]['Matches_Played'],top_bowlers.iloc[0]['Matches_Played'],top_bowlers.iloc[7]['Matches_Played'],top_bowlers.iloc[1]['Matches_Played']]
Wickets_values= [top_bowlers.iloc[10]['Wickets'],top_bowlers.iloc[0]['Wickets'],top_bowlers.iloc[7]['Wickets'],top_bowlers.iloc[1]['Wickets']]
Bowling_average_values= [top_bowlers.iloc[10]['Bowling_average'],top_bowlers.iloc[0]['Bowling_average'],top_bowlers.iloc[7]['Bowling_average'],top_bowlers.iloc[1]['Bowling_average']]
Bowling_Strike_Rate_values=[top_bowlers.iloc[10]['Bowling_Strike_Rate'],top_bowlers.iloc[0]['Bowling_Strike_Rate'],top_bowlers.iloc[7]['Bowling_Strike_Rate'],top_bowlers.iloc[1]['Bowling_Strike_Rate']]
Economy_values= [top_bowlers.iloc[10]['Economy'],top_bowlers.iloc[0]['Economy'],top_bowlers.iloc[7]['Economy'],top_bowlers.iloc[1]['Economy']]

# %%
fig,axes=plt.subplots(3,2, figsize=(20,15))

axes[0][0].set_title('Matches')
axes[0][1].set_title('Wickets')
axes[1][0].set_title('Bowling_average')
axes[1][1].set_title('Bowling_Strike_Rate')
axes[2][0].set_title('Economy')

sns.barplot(x=labels, y=Matches_Played_values, ax=axes[0][0])
sns.barplot(x=labels, y=Wickets_values, ax=axes[0][1])
sns.barplot(x=labels, y=Bowling_average_values, ax=axes[1][0])
sns.barplot(x=labels, y=Bowling_Strike_Rate_values, ax=axes[1][1])
sns.barplot(x=labels, y=Economy_values, ax=axes[2][0])

# %% [markdown]
# #Top_keepers visualizations

# %%
matches_playes= 
average_values=
keeping_values=

# %%
top_keepers.reset_index(drop=True)
# Out:
#        Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 0  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 1    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 2     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 3   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 4   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 5        KS Bharat      Delhi      Indian             8.0   191.0    38.20
# 6    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 7     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 8         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 9       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
#
#    Strike_Rate  Catches  Run_outs  Stumps
# 0       130.90     53.0       0.0    14.0
# 1       127.50     58.0      12.0     2.0
# ...

# %%
matches_plays= [top_keepers.iloc[8]['Matches_Played'],top_keepers.iloc[8]['Runs']]
average_values=[top_keepers.iloc[8]['Average'],top_keepers.iloc[8]['Strike_Rate']]
keeping_values=[top_keepers.iloc[8]['Catches'],top_keepers.iloc[8]['Stumps'],top_keepers.iloc[8]['Run_outs']]

# %%
label1= ['Matches', 'Runs']
label2= ['Average', 'Strike_Rate']
label3= ['Catches', 'Stumps','Run_outs']

# %%
fig,axes=plt.subplots(1,3, figsize=(20,10))

axes[0].set_title('Matches and Runs')
axes[1].set_title('Average and strike_rate')
axes[2].set_title('keeper_stats')

sns.barplot(x=label1, y=matches_plays, ax=axes[0])
sns.barplot(x=label2, y=average_values, ax=axes[1])
sns.barplot(x=label3, y=keeping_values, ax=axes[2])
